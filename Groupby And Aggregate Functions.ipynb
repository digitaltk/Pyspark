# %%
from pyspark.sql import SparkSession
spark=SparkSession

# %%
spark=SparkSession.builder.appName('functions').getOrCreate()

# %%
df_pyspark=spark.read.csv('MOCK_DATA.csv',header=True,inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---+----------+-----------+--------------------+-----------+---------------+
# | id|first_name|  last_name|               email|     gender|     ip_address|
# +---+----------+-----------+--------------------+-----------+---------------+
# |  1|       Der|    Guthrie|  dguthrie0@dmoz.org|Genderfluid|   84.199.30.53|
# |  2|     Wilow|  MacAiline|wmacailine1@fotki...|Genderfluid| 105.73.152.225|
# |  3|   Ignacio|     Elgood|       ielgood2@t.co|   Bigender| 120.172.82.158|
# |  4|   Xymenes|     Angeli|  xangeli3@desdev.cn|     Female| 50.240.252.201|
# |  5|    Egbert|  Glaserman|eglaserman4@tamu.edu|Genderfluid| 185.86.126.206|
# |  6|  Ninnetta|    Burgill|nburgill5@utexas.edu|Genderqueer|  234.104.44.29|
# |  7|     Adamo|    Haydney|ahaydney6@so-net....|   Bigender|    98.182.4.12|
# |  8|     Belva|     Thrift|bthrift7@constant...|Genderqueer|    38.154.94.3|
# |  9|  Nicholas|      Rathe|nrathe8@ycombinat...|Genderqueer|  64.117.235.16|
# ...

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- ip_address: string (nullable = true)

# %%
##groupBy

# GroupbyGender and show the total 
df_pyspark.groupBy('gender').sum().show()
# Out:
# +-----------+-------+
# |     gender|sum(id)|
# +-----------+-------+
# |Genderqueer|  65795|
# |    Agender|  62884|
# |     Female|  59329|
# | Polygender|  64793|
# |   Bigender|  60689|
# | Non-binary|  59516|
# |       Male|  57494|
# |Genderfluid|  70000|
# +-----------+-------+

# %%
##Count the different groups 

df_pyspark.groupBy('gender').count().show()
# Out:
# +-----------+-----+
# |     gender|count|
# +-----------+-----+
# |Genderqueer|  131|
# |    Agender|  127|
# |     Female|  122|
# | Polygender|  130|
# |   Bigender|  123|
# | Non-binary|  121|
# |       Male|  113|
# |Genderfluid|  133|
# +-----------+-----+

# %%
df_pyspark.agg({'id':'sum'}).show()
# Out:
# +-------+
# |sum(id)|
# +-------+
# | 500500|
# +-------+

# %%
# df_pyspark.groupBy('gender').max().show()
