# %%
import pandas as pd
# build pyspark session
from pyspark.sql import SparkSession

# %%
spark= SparkSession.builder.appName('CompanyData').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.20.10.5:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CompanyData</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#read dataset
df_pyspark = spark.read.option('header','true').csv('MOCK_DATA.csv',inferSchema=True)

# %%
## check schema, the data types
df_pyspark.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- ip_address: string (nullable = true)

# %%
df_pyspark=spark.read.csv('MOCK_DATA.csv',header=True,inferSchema=True)

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- ip_address: string (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address']

# %%
df_pyspark.head(3)
# Out:
# [Row(id=1, first_name='Der', last_name='Guthrie', email='dguthrie0@dmoz.org', gender='Genderfluid', ip_address='84.199.30.53'),
#  Row(id=2, first_name='Wilow', last_name='MacAiline', email='wmacailine1@fotki.com', gender='Genderfluid', ip_address='105.73.152.225'),
#  Row(id=3, first_name='Ignacio', last_name='Elgood', email='ielgood2@t.co', gender='Bigender', ip_address='120.172.82.158')]

# %%
#how to select a comullm
df_pyspark.show()
# Out:
# +---+----------+-----------+--------------------+-----------+---------------+
# | id|first_name|  last_name|               email|     gender|     ip_address|
# +---+----------+-----------+--------------------+-----------+---------------+
# |  1|       Der|    Guthrie|  dguthrie0@dmoz.org|Genderfluid|   84.199.30.53|
# |  2|     Wilow|  MacAiline|wmacailine1@fotki...|Genderfluid| 105.73.152.225|
# |  3|   Ignacio|     Elgood|       ielgood2@t.co|   Bigender| 120.172.82.158|
# |  4|   Xymenes|     Angeli|  xangeli3@desdev.cn|     Female| 50.240.252.201|
# |  5|    Egbert|  Glaserman|eglaserman4@tamu.edu|Genderfluid| 185.86.126.206|
# |  6|  Ninnetta|    Burgill|nburgill5@utexas.edu|Genderqueer|  234.104.44.29|
# |  7|     Adamo|    Haydney|ahaydney6@so-net....|   Bigender|    98.182.4.12|
# |  8|     Belva|     Thrift|bthrift7@constant...|Genderqueer|    38.154.94.3|
# |  9|  Nicholas|      Rathe|nrathe8@ycombinat...|Genderqueer|  64.117.235.16|
# ...

# %%
df_pyspark.select(['email','last_name']).head(3)
# Out:
# [Row(email='dguthrie0@dmoz.org', last_name='Guthrie'),
#  Row(email='wmacailine1@fotki.com', last_name='MacAiline'),
#  Row(email='ielgood2@t.co', last_name='Elgood')]

# %%
df_pyspark['first_name']
# Out:
# Column<'first_name'>

# %%
df_pyspark.dtypes
# Out:
# [('id', 'int'),
#  ('first_name', 'string'),
#  ('last_name', 'string'),
#  ('email', 'string'),
#  ('gender', 'string'),
#  ('ip_address', 'string')]

# %%
df_pyspark.describe().show()
# Out:
# +-------+-----------------+----------+---------+-------------------+----------+-------------+
# |summary|               id|first_name|last_name|              email|    gender|   ip_address|
# +-------+-----------------+----------+---------+-------------------+----------+-------------+
# |  count|             1000|      1000|     1000|               1000|      1000|         1000|
# |   mean|            500.5|      null|     null|               null|      null|         null|
# | stddev|288.8194360957494|      null|     null|               null|      null|         null|
# |    min|                1|     Abbye| Abramzon|aarnallg4@chron.com|   Agender|  0.109.124.7|
# |    max|             1000|    Zondra| Zisneros|   zsyrie15@dot.gov|Polygender|99.204.174.23|
# +-------+-----------------+----------+---------+-------------------+----------+-------------+

# %%
##Adding Comulms in Pyspark

df_pyspark=df_pyspark.withColumn('Ip Address Modified',df_pyspark['ip_address']+2)

# %%
df_pyspark
# Out:
# DataFrame[id: int, first_name: string, last_name: string, email: string, gender: string, ip_address: string, Ip Address Modified: double]

# %%
##Drop or Delete Columns

df_pyspark=df_pyspark.drop('Ip Address Modified').show()
# Out:
# +---+----------+-----------+--------------------+-----------+---------------+
# | id|first_name|  last_name|               email|     gender|     ip_address|
# +---+----------+-----------+--------------------+-----------+---------------+
# |  1|       Der|    Guthrie|  dguthrie0@dmoz.org|Genderfluid|   84.199.30.53|
# |  2|     Wilow|  MacAiline|wmacailine1@fotki...|Genderfluid| 105.73.152.225|
# |  3|   Ignacio|     Elgood|       ielgood2@t.co|   Bigender| 120.172.82.158|
# |  4|   Xymenes|     Angeli|  xangeli3@desdev.cn|     Female| 50.240.252.201|
# |  5|    Egbert|  Glaserman|eglaserman4@tamu.edu|Genderfluid| 185.86.126.206|
# |  6|  Ninnetta|    Burgill|nburgill5@utexas.edu|Genderqueer|  234.104.44.29|
# |  7|     Adamo|    Haydney|ahaydney6@so-net....|   Bigender|    98.182.4.12|
# |  8|     Belva|     Thrift|bthrift7@constant...|Genderqueer|    38.154.94.3|
# |  9|  Nicholas|      Rathe|nrathe8@ycombinat...|Genderqueer|  64.117.235.16|
# ...

# %%
##Rename the column
df_pyspark.withColumnRenamed('first_name','First Name').show()
# Out:
# +---+----------+-----------+--------------------+-----------+---------------+
# | id|First Name|  last_name|               email|     gender|     ip_address|
# +---+----------+-----------+--------------------+-----------+---------------+
# |  1|       Der|    Guthrie|  dguthrie0@dmoz.org|Genderfluid|   84.199.30.53|
# |  2|     Wilow|  MacAiline|wmacailine1@fotki...|Genderfluid| 105.73.152.225|
# |  3|   Ignacio|     Elgood|       ielgood2@t.co|   Bigender| 120.172.82.158|
# |  4|   Xymenes|     Angeli|  xangeli3@desdev.cn|     Female| 50.240.252.201|
# |  5|    Egbert|  Glaserman|eglaserman4@tamu.edu|Genderfluid| 185.86.126.206|
# |  6|  Ninnetta|    Burgill|nburgill5@utexas.edu|Genderqueer|  234.104.44.29|
# |  7|     Adamo|    Haydney|ahaydney6@so-net....|   Bigender|    98.182.4.12|
# |  8|     Belva|     Thrift|bthrift7@constant...|Genderqueer|    38.154.94.3|
# |  9|  Nicholas|      Rathe|nrathe8@ycombinat...|Genderqueer|  64.117.235.16|
# ...
